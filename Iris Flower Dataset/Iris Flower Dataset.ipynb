# %% [markdown]
# # Iris Flower Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

iris = pd.read_csv("C:/Users/Johnny/Desktop/Data Science/Iris Flower Dataset/iris.csv")

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.columns)
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris["Species"].value_counts()
# Out:
# Iris_setosa        50
# Iris_versicolor    50
# Iris_virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # 2-D Scatter Plot

# %%
iris.plot(kind = "scatter", x = "SepalLengthCm", y = "SepalWidthCm" )
plt.show()

# %%
sns.set_style("whitegrid")
sns.FacetGrid(iris, hue = "Species", height = 5) \
.map(plt.scatter, "SepalLengthCm", "SepalWidthCm") \
.add_legend()
plt.show()

# %% [markdown]
# ###### Observations:
# 1. Using SepalLengthCm and SepalWidthCm features, we can distinguish Setosa flower from others.
# 2. Separating Versicolor from Virginica is much harder as they have considerable overlap.

# %% [markdown]
# # Pair-plot

# %%
sns.set_style("whitegrid")
sns.pairplot(iris, hue = "Species", height = 5)
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ###### Obervations:
# 1. PetalLengthCm and PetalWidthCm are the most useful features to identify various flower types.
# 2. While Setosa can be easily identified (linearly seperable), Virginica and Versicolor have some overlap (almost linearly seperable).
# 3. We can find "lines" and "if-else" conditions to build a simple model to classify the flower types.

# %% [markdown]
# # Univariate analysis

# %%
sns.FacetGrid(iris, hue = "Species", height = 5) \
.map(sns.distplot, "PetalLengthCm").add_legend()
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.FacetGrid(iris, hue = "Species", height = 5) \
.map(sns.distplot, "PetalWidthCm").add_legend()
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.FacetGrid(iris, hue = "Species", height = 5) \
.map(sns.distplot, "SepalLengthCm").add_legend()
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.FacetGrid(iris, hue = "Species", height = 5) \
.map(sns.distplot, "SepalWidthCm").add_legend()
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# # Mean, Variance & Std-Dev, Quantile, Percentile

# %%
iris_numpy = np.asarray(iris)

Iris_setosa = iris_numpy[0:50]
Iris_versicolor = iris_numpy[50:100]
Iris_virginica = iris_numpy[100:]

print("Petal Length")
print("============")
print("Means:")
print(np.mean(Iris_setosa[0:50,3]))
print(np.mean(Iris_versicolor[0:50,3]))
print(np.mean(Iris_virginica[0:50,3]))
print()
print("Std-dev:")
print(np.std(Iris_setosa[0:50,3]))
print(np.std(Iris_versicolor[0:50,3]))
print(np.std(Iris_virginica[0:50,3]))
print()
print("Medians:")
print(np.median(Iris_setosa[0:50,3]))
print(np.median(Iris_versicolor[0:50,3]))
print(np.median(Iris_virginica[0:50,3]))
print()
print("Quantiles:")
print(np.percentile(Iris_setosa[0:50,3],np.arange(0, 100, 25)))
print(np.percentile(Iris_versicolor[0:50,3],np.arange(0, 100, 25)))
print(np.percentile(Iris_virginica[0:50,3],np.arange(0, 100, 25)))
print()
print("90th Percentiles:")
print(np.percentile(Iris_setosa[0:50,3],90))
print(np.percentile(Iris_versicolor[0:50,3],90))
print(np.percentile(Iris_virginica[0:50,3],90))
# Out:
# Petal Length
# ...
# Means:
# 1.464
# 4.26
# 5.552
#
# Std-dev:
# 0.17176728442867115
# 0.4651881339845204
# 0.5463478745268441
#
# Medians:
# 1.5
# 4.35
# 5.55
#
# Quantiles:
# [1.0 1.4 1.5 1.5750000000000002]
# [3.0 4.0 4.35 4.6]
# [4.5 5.1 5.55 5.875000000000001]
#
# 90th Percentiles:
# 1.7
# 4.8
# 6.3100000000000005

# %% [markdown]
# # Box plot and Whiskers

# %%
sns.boxplot(x = "Species", y = "PetalLengthCm", data = iris)
plt.show()

# %% [markdown]
# # Violin plots

# %%
sns.violinplot(x = "Species", y = "PetalLengthCm", data = iris)
plt.show()
# Out:
# C:\tools\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
