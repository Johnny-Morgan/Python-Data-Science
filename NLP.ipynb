# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
from nltk.corpus import movie_reviews
movie_reviews.fileids()
print(movie_reviews.raw("neg/cv000_29416.txt"))
# Out:
# plot : two teen couples go to a church party , drink and then drive .
# they get into an accident .
# one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares .
# what's the deal ?
# watch the movie and " sorta " find out . . .
# critique : a mind-fuck movie for the teen generation that touches on a very cool idea , but presents it in a very bad package .
# which is what makes this review an even harder one to write , since i generally applaud films which attempt to break the mold , mess with your head and such ( lost highway & memento ) , but there are good and bad ways of making all types of films , and these folks just didn't snag this one correctly .
# they seem to have taken this pretty neat concept , but executed it terribly .
# so what are the problems with the movie ?
# well , its main problem is that it's simply too jumbled .
# ...

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

example_text = ("Hello Mr. Jones, how are you doing today? The weather is great. The sky is pinkish-blue. You shouldn't need an umbrella.")

print(sent_tokenize(example_text))
# Out:
# ['Hello Mr. Jones, how are you doing today?', 'The weather is great.', 'The sky is pinkish-blue.', "You shouldn't need an umbrella."]

# %%
print(word_tokenize(example_text))
# Out:
# ['Hello', 'Mr.', 'Jones', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'need', 'an', 'umbrella', '.']

# %%
from nltk.corpus import stopwords
print(set(stopwords.words('english')))
# Out:
# {'because', 'while', 'won', "don't", 'into', 'had', "needn't", 'i', "weren't", "it's", 'am', "won't", "you've", "hadn't", 'few', 'have', 'against', 'themselves', 'over', 'such', "she's", 't', 'about', 'then', 'by', 'haven', 'in', 'did', 'didn', 'needn', 'where', 'from', 'again', 'being', 'my', 'for', 'nor', 'of', 'if', 'hadn', 'no', 'were', 'can', "mightn't", 've', 'some', 'hers', 'doing', 'only', 'been', 'out', 'once', 'he', 'to', 'myself', 'after', "didn't", "haven't", 'wouldn', 'shouldn', 'weren', 'but', 'further', 'during', 'couldn', 'ourselves', 'isn', 'through', 'whom', 'ain', 'him', 'any', 'y', 'll', 'them', 's', "shouldn't", 'himself', 'own', 'shan', 'these', 'very', "that'll", 'other', 'not', 'm', 'theirs', 'here', 'with', "you'll", 'mightn', 'both', "hasn't", "aren't", 'or', 'does', 'as', 'mustn', 'just', "wasn't", 'itself', 'more', 'down', 'her', 'up', 'off', 'doesn', 'an', 'too', "you're", 'me', 'their', 'ma', 'his', 'a', 'same', "shan't", 'don', 'which', 'each', 'so', "s
# ...

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize

example_sent = "This is a sample sentence, showing off the stop words filtration"

stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)

filtered_sentence = [w for w in word_tokens if not w in stop_words]

filtered_sentence
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration']
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration']

# %%
# Alternative to list comprehension approach:
filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
        
filtered_sentence
# Out:
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration']

# %%
from nltk.corpus import movie_reviews
movie_reviews.fileids()
movie_text = (movie_reviews.raw("neg/cv000_29416.txt"))
word_tokens = word_tokenize(movie_text)

filtered_movie_text = [w for w in word_tokens if not w in stop_words]

filtered_movie_text
# Out:
# ['plot',
#  ':',
#  'two',
#  'teen',
#  'couples',
#  'go',
#  'church',
#  'party',
#  ',',
#  'drink',
#  'drive',
#  '.',
#  'get',
#  'accident',
#  '.',
#  'one',
#  'guys',
#  'dies',
#  ',',
#  'girlfriend',
#  'continues',
#  'see',
#  'life',
#  ',',
#  'nightmares',
#  '.',
#  "'s",
#  'deal',
#  '?',
#  'watch',
#  'movie',
#  '``',
#  'sorta',
#  '``',
#  'find',
#  '.',
#  '.',
#  '.',
#  'critique',
#  ':',
#  'mind-fuck',
#  'movie',
#  'teen',
#  'generation',
#  'touches',
#  'cool',
#  'idea',
#  ',',
#  'presents',
#  'bad',
#  'package',
#  '.',
#  'makes',
#  'review',
#  'even',
#  'harder',
#  'one',
#  'write',
#  ',',
#  'since',
#  'generally',
#  'applaud',
#  'films',
#  'attempt',
#  'break',
#  'mold',
#  ',',
#  'mess',
#  'head',
#  '(',
#  'lost',
#  'highway',
#  '&',
#  'memento',
#  ')',
#  ',',
#  'good',
#  'bad',
#  'ways',
#  'making',
#  'types',
#  'films',
#  ',',
#  'folks',
#  "n't",
#  'snag',
#  'one',
#  'correctly',
#  '.',
# ...

# %% [markdown]
# # Stemming words

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

example = "semantically, semantics, semantic, destructiveness, destructive"

words = word_tokenize(example)

for w in words:
    print(ps.stem(w))
# Out:
# semant
# ,
# semant
# ,
# semant
# ,
# destruct
# ,
# destruct

# %% [markdown]
# # Stemming words example

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

ps = PorterStemmer()

sentence1 = "The house was haunted."
sentence2 = "It was a haunting experience"
sentence3 = "The ghost will haunt any visitors"

words1 = word_tokenize(sentence1) 
words2 = word_tokenize(sentence2)
words3 = word_tokenize(sentence3)

stemmed_words1 = []
stemmed_words2 = []
stemmed_words3 = []

for w in words1: 
    stemmed_words1.append(ps.stem(w))
for w in words2: 
    stemmed_words2.append(ps.stem(w))
for w in words3: 
    stemmed_words3.append(ps.stem(w))
    
print("Stemmed sentence 1 = ", stemmed_words1)
print("Stemmed sentence 2 = ", stemmed_words2)
print("Stemmed sentence 3 = ", stemmed_words3)
# Out:
# Stemmed sentence 1 =  ['the', 'hous', 'wa', 'haunt', '.']
# Stemmed sentence 2 =  ['It', 'wa', 'a', 'haunt', 'experi']
# Stemmed sentence 3 =  ['the', 'ghost', 'will', 'haunt', 'ani', 'visitor']

# %% [markdown]
# # Create a string containing 2-3 sentences, tokenise it, remove stop words, and stem. View the output to get a better understanding of the end result of stemming on a variety of words.

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

ps = PorterStemmer()

sentence = "Karma police arrest this man he talks in maths. He buzzes like a fridge, he's like a detuned radio. Karma police arrest this girl her Hitler hairdo. It's making me feel ill and we have crashed her party"

words = word_tokenize(sentence) 

stop_words = set(stopwords.words('english'))

words = [w for w in words if not w in stop_words]

stemmed_words = []


for w in words: 
    stemmed_words.append(ps.stem(w))

    
print("Stemmed sentence = ", stemmed_words)
# Out:
# Stemmed sentence =  ['karma', 'polic', 'arrest', 'man', 'talk', 'math', '.', 'He', 'buzz', 'like', 'fridg', ',', "'s", 'like', 'detun', 'radio', '.', 'karma', 'polic', 'arrest', 'girl', 'hitler', 'hairdo', '.', 'It', "'s", 'make', 'feel', 'ill', 'crash', 'parti']

# %%
from nltk.corpus import movie_reviews
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

ps = PorterStemmer()

stop_words = set(stopwords.words('english'))

stemmed_movie = []

for w in movie_reviews.words("neg/cv016_4348.txt"):
    if w not in stop_words:
        stemmed_movie.append(ps.stem(w))
        
print(stemmed_movie)
# Out:
# ["'", 'realli', 'start', 'wonder', 'alicia', 'silverston', '.', 'sure', ',', 'one', 'beauti', 'creatur', 'god', "'", 'green', 'earth', '(', 'second', 'movi', 'critic', 'larg', 'guy', ')', ',', 'come', 'choos', 'movi', 'star', ',', 'alway', 'strike', '.', 'crush', 'slow', '-', 'move', ',', 'predict', 'piec', 'fluff', '.', 'hideaway', 'horrif', 'novel', 'adapt', 'alicia', 'minor', 'role', '.', 'clueless', 'annoy', ',', 'unfunni', 'wast', 'time', '.', 'peopl', 'e', '-', 'mail', ',', 'say', 'clueless', 'good', 'movi', "'", 'one', "'", 'like', '.', 'one', 'girl', 'said', "'", 'seen', 'movi', '"', 'open', 'mind', ',', '"', 'would', 'enjoy', '.', 'noth', 'could', 'truth', '.', 'went', 'theater', 'expect', 'love', 'movi', '.', 'preview', 'look', 'good', 'cours', "'", 'crazymadinlov', 'alicia', ',', 'movi', 'bunch', 'bad', 'joke', 'come', 'whini', ',', 'unlik', 'charact', '.', 'almost', 'everyon', 'saw', 'movi', 'felt', 'way', '.', 'walk', 'theater', ',', 'one', 'guy', '(', "'", ')', 'yell', 
# ...

# %% [markdown]
# # Text Classification with NLTK

# %%
import nltk
import random
from nltk.corpus import movie_reviews

# Step 1 – Create a list of tuples for all movie reviews. Each tuple contains:
# • The list of words in the current review
# • The category of review e.g. Positive / Negative

documents = []

for category in movie_reviews.categories():
    for fileid in movie_reviews.fileids(category): 
        item = (movie_reviews.words(fileid), category)
        documents.append(item)

# %%
# Step 2:
# • Shuffle the documents ( to mix Positive / Negative reviews)
# • Create a list of all words in all documents

random.shuffle(documents)
all_words = []
for w in movie_reviews.words():
    all_words.append(w.lower())
print(all_words[0:100])
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', 'a', 'church', 'party', ',', 'drink', 'and', 'then', 'drive', '.', 'they', 'get', 'into', 'an', 'accident', '.', 'one', 'of', 'the', 'guys', 'dies', ',', 'but', 'his', 'girlfriend', 'continues', 'to', 'see', 'him', 'in', 'her', 'life', ',', 'and', 'has', 'nightmares', '.', 'what', "'", 's', 'the', 'deal', '?', 'watch', 'the', 'movie', 'and', '"', 'sorta', '"', 'find', 'out', '.', '.', '.', 'critique', ':', 'a', 'mind', '-', 'fuck', 'movie', 'for', 'the', 'teen', 'generation', 'that', 'touches', 'on', 'a', 'very', 'cool', 'idea', ',', 'but', 'presents', 'it', 'in', 'a', 'very', 'bad', 'package', '.', 'which', 'is', 'what', 'makes', 'this', 'review', 'an', 'even', 'harder', 'one', 'to']

# %%
# Step 3 – Create a Frequency Distribution object of all words
# • Use the most_common() function to return the top x most common words
# • We can provide a word as a key, to get the number of occurrences of that word

all_words = nltk.FreqDist(all_words)

print(all_words.most_common(20))
print()
print("The word whiskey appears %s times" % all_words["whiskey"])
# Out:
# [(',', 77717), ('the', 76529), ('.', 65876), ('a', 38106), ('and', 35576), ('of', 34123), ('to', 31937), ("'", 30585), ('is', 25195), ('in', 21822), ('s', 18513), ('"', 17612), ('it', 16107), ('that', 15924), ('-', 15595), (')', 11781), ('(', 11664), ('as', 11378), ('with', 10792), ('for', 9961)]
#
# The word whiskey appears 8 times
